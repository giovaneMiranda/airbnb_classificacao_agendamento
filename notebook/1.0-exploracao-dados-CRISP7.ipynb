# %% [markdown]
# # Problema de Negocio

# %% [markdown]
# Airbnb opera no mercado online de hospedagem, principalmente com casas de família para aluguel de temporada e atividade de turismo. No memento se observou a necessidade de prever o primeiro destino que um novo usuário vai escolher para fazer sua reserva de hospedagem.
#
# **Causa raiz**: Por se tratar de um modelo de marketplace, onde visa conectar pessoas que oferecem um serviço, com pessoas que estão em busca dos mesmo, a necessidade vem de prever o destino para melhor aplicar a campanha de marketing. Buscando diminuir o CAC.

# %% [markdown]
# ## Planejamento da Entrega

# %% [markdown]
# 1. Resposta
# - prever o destino do primeiro agendamento de hospedagem do usuário.
#
# 2. Formato de entrega
# - Json com os dados do cliente e a classificação do destino.
#
# 3. Local de entrega
# - Api

# %% [markdown]
# ## Planejamento do Processo

# %% [markdown]
# 1. Extração e carregamento dos dados.
# 2. Análise descritiva e  do dataset.
# 3. Validação e tratamento de dados faltantes
# 4. Feature engineering
# 5. Balanceamento dos dados.
# 6. EAD.
# 7. Modelagem de dados
# 8. Seleção dos atributos relevantes
# 9. Modelagem de algoritmo classificador e fine tunning
# 10. Criação Class Pipeline de dados e API Handler
# 11. Deploy em produção

# %% [markdown]
# ## Planejamento de Entrada

# %% [markdown]
# 1. Fonte dos dados
# - **kaggle** https://www.kaggle.com/c/airbnb-recruiting-new-user-bookings/data
#
# 2. Ferramentas
# - Python 3
# - Flask
# - Sklearn
# - Jupyter Notebook
# - Heroku

# %% [markdown]
# # 0.0 Import

# %%
import pandas as pd 
import matplotlib.pyplot
import random
import numpy as np
import scipy.stats as stats

import sklearn.preprocessing as pp
import sklearn.model_selection as ms
from keras import models as ml
from keras import layers as l
from sklearn import metrics
from scikitplot import metrics as mt
from imblearn import combine
from category_encoders import TargetEncoder

#visualizacao 
import seaborn as sns
from IPython.display import Image
from IPython.core.display  import HTML
import matplotlib.pyplot as plt
from pandas_profiling import ProfileReport


import os

# %% [markdown]
# ## 0.1 Helper Functions

# %%
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '2'

def jupyter_settings():
    # %matplotlib inline 
    # %pylab inline
    
    plt.style.use( 'bmh' )
    plt.rcParams['figure.figsize'] = [25, 12]
    
    
    display( HTML( '<style>.container { width:80% !important; }</style>') )
    pd.options.display.max_columns = None

def cramer_v(x , y):
    conf_matrix = pd.crosstab(x,y).values
    n = conf_matrix.sum()
    r, k = conf_matrix.shape
    
    chi2 = stats.chi2_contingency(conf_matrix)[0]
    
    chi2_corr = max(0, chi2 - (k-1) * (r-1)/(n-1))
    k_corr = k-(k-1)**2 / (n-1)
    r_corr = r - (r-1)**2 / (n-1)
    
    return np.sqrt((chi2_corr/n) / (min(k-1, r-1) ) )

jupyter_settings()
# Out:
# %pylab is deprecated, use %matplotlib inline and import the required libraries.
# Populating the interactive namespace from numpy and matplotlib
# /home/giovane/Documentos/repo/airbnb_previsao_agendamento/airbnb_booking/lib/python3.8/site-packages/IPython/core/magics/pylab.py:162: UserWarning: pylab import has clobbered these variables: ['random']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +
# <style>.container { width:80% !important; }</style>

# %% [markdown]
# ## 0.2 Carregamento de dados

# %%
df_user_raw = pd.read_csv('/home/giovane/Documentos/repo/airbnb_previsao_agendamento/data/raw/train_users_2.csv')
df_sessions_raw = pd.read_csv('/home/giovane/Documentos/repo/airbnb_previsao_agendamento/data/raw/sessions.csv')

# %% [markdown]
# # 1.0 Análise Descritiva

# %%
# verificando o a dimensao dos dados (Linhas e colunas)
# Tipo dos atributos 
df_user_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213451 entries, 0 to 213450
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count   Dtype
# ---  ------                   --------------   -----
#  0   id                       213451 non-null  object
#  1   date_account_created     213451 non-null  object
#  2   timestamp_first_active   213451 non-null  int64
#  3   date_first_booking       88908 non-null   object
#  4   gender                   213451 non-null  object
#  5   age                      125461 non-null  float64
#  6   signup_method            213451 non-null  object
#  7   signup_flow              213451 non-null  int64
#  8   language                 213451 non-null  object
#  9   affiliate_channel        213451 non-null  object
#  10  affiliate_provider       213451 non-null  object
#  11  first_affiliate_tracked  207386 non-null  object
#  12  signup_app               213451 non-null  object
#  13  first_device_type        213451 non-null  object
#  14  first_browser            213451 non-null  object
#  15  country_destination      213451 non-null  object
# dtypes: float64(1), int64(2), object(13)
# memory usage: 26.1+ MB

# %%
df_sessions_raw.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10567737 entries, 0 to 10567736
# Data columns (total 6 columns):
#  #   Column         Dtype
# ---  ------         -----
#  0   user_id        object
#  1   action         object
#  2   action_type    object
#  3   action_detail  object
#  4   device_type    object
#  5   secs_elapsed   float64
# dtypes: float64(1), object(5)
# memory usage: 483.8+ MB

# %% [markdown]
# ## 1.2 Dados Faltantes ( NA )

# %%
# Verificando a porcentagem de NA no dataset de usuario 
df_user_raw.isna().sum() / len(df_user_raw)
# Out:
# id                         0.000000
# date_account_created       0.000000
# timestamp_first_active     0.000000
# date_first_booking         0.583473
# gender                     0.000000
# age                        0.412226
# signup_method              0.000000
# signup_flow                0.000000
# language                   0.000000
# affiliate_channel          0.000000
# affiliate_provider         0.000000
# first_affiliate_tracked    0.028414
# signup_app                 0.000000
# first_device_type          0.000000
# first_browser              0.000000
# country_destination        0.000000
# dtype: float64

# %% [markdown]
# O df_user_raw possui 3 colunas onde apresentam dados faltantes( NA )
# - date_first_booking
# - age
# - first_affiliate_tracked

# %%
# Verificando a porcentagem de NA no dataset de sessao
df_sessions_raw.isna().sum() / len(df_sessions_raw)
# Out:
# user_id          0.003264
# action           0.007535
# action_type      0.106570
# action_detail    0.106570
# device_type      0.000000
# secs_elapsed     0.012872
# dtype: float64

# %% [markdown]
# O df_user_raw possui 5 colunas onde apresentam dados faltantes( NA )
# - user_id
# - action
# - action_type
# - action_detail
# - secs_elapsed

# %% [markdown]
# ## 1.3 Preenchendo NA

# %% [markdown]
# ### 1.3.1 Atributo date_first_booking

# %%
# date_first_booking 
# Verificando a procentagem de NA do date_first_booking por Classe do destino
df_user_raw[df_user_raw['date_first_booking'].isna()]['country_destination'].value_counts(normalize=True)
# Out:
# NDF    1.0
# Name: country_destination, dtype: float64

# %%
# substituindo NA
date_booking_max = pd.to_datetime(df_user_raw['date_first_booking']).max().strftime('%Y-%m-%d')
df_user_raw['date_first_booking'].fillna(value=date_booking_max, inplace=True)

# %% [markdown]
# Complentando NA do date_first_booking  com a data maxima do dataset, ja que a falta do dado se da pelo fato do usuario nao ter feito booking

# %% [markdown]
# ### 1.3.2 Atributo age

# %%
# age
# Verificando a procentagem de NA do age por Classe do destino
df_user_raw[df_user_raw['age'].isna()]['country_destination'].value_counts(normalize=True)
# Out:
# NDF      0.768428
# US       0.156529
# other    0.028617
# FR       0.014888
# IT       0.009081
# GB       0.006251
# ES       0.006171
# CA       0.003989
# DE       0.002387
# NL       0.001818
# AU       0.001171
# PT       0.000671
# Name: country_destination, dtype: float64

# %% [markdown]
# A distrubuicao de Na's aparentemente segue a proporcao de registros nas classe.

# %%
df_age =  df_user_raw[df_user_raw['age'] < 120] 
sns.displot(data = df_age['age'], kind = 'kde');

# %% [markdown]
# O atributo age segue uma distribuicao parecida com a Normal, logo, podemos substituir os NA's pela media e o desvio padrao, sem perigos de imputar um vies nos registros.

# %%
df_user_raw['age'].fillna(value=df_age['age'].mean().astype( int ), inplace=True)

# %% [markdown]
# ### 1.3.3 Atributo first_affiliate_tracked

# %%
df_user_raw['first_affiliate_tracked'].value_counts(normalize=True)
# Out:
# untracked        0.526709
# linked           0.223193
# omg              0.212078
# tracked-other    0.029684
# product          0.007503
# marketing        0.000670
# local ops        0.000164
# Name: first_affiliate_tracked, dtype: float64

# %% [markdown]
# Por se tratar de uma variavel categoria, a substituicao das Na's pode acabar imputando vies no Dataset.
# Visto que os Na's representao apenas 3% do total dos dados, sera realizado o drop dos memos.

# %%
df_user_raw = df_user_raw[~df_user_raw['first_affiliate_tracked'].isna()]

# %% [markdown]
# ### 1.3.4  Atributos df_sessions

# %%
# Drop na user_id, action, action_type, action_detail, secs_elapsed
df_sessions_raw.dropna(inplace= True)

# %% [markdown]
# ## 1.4 Alterando Data Type

# %%
df_user_raw['date_account_created'] = pd.to_datetime(df_user_raw['date_account_created'])  
df_user_raw['timestamp_first_active'] = pd.to_datetime(df_user_raw['timestamp_first_active'], format='%Y%m%d%H%M%S') 
df_user_raw['date_first_booking'] = pd.to_datetime(df_user_raw['date_first_booking'])  
df_user_raw['age'] = df_user_raw['age'].astype(int)

# %% [markdown]
# ## 1.5 Estatistica Descritiva

# %%
# Separando dados em Numericos e Categoricos para o usuario
num_attributes = df_user_raw.select_dtypes(include=['int64', 'float64'])
cat_attributes = df_user_raw.select_dtypes(exclude=['int64', 'float64', 'datetime64[ns]'])
date_attributes = df_user_raw.select_dtypes(include=['datetime64'])

# Separando dados em Numericos e Categoricos para o Sessao
num_attributes_sessions = df_sessions_raw.select_dtypes(include=['int64', 'float64'])
cat_attributes_sessions  = df_sessions_raw.select_dtypes(exclude=['int64', 'float64', 'datetime64[ns]'])
date_attributes_sessions  = df_sessions_raw.select_dtypes(include=['datetime64'])

# %% [markdown]
# ### 1.5.1 Atributos Numericos - Usuario

# %%
# estatistica de tendencia central
num_mean = pd.DataFrame(num_attributes.mean()) 
num_median = pd.DataFrame(num_attributes.median())

# estatistica de dispersao 
num_std      = pd.DataFrame(num_attributes.std()) 
num_min      = pd.DataFrame(num_attributes.min())
num_max      = pd.DataFrame(num_attributes.max())
num_range    = pd.DataFrame(num_attributes.apply(lambda x : x.max()-x.min()))
num_skew     = pd.DataFrame(num_attributes.skew())
num_kurtosis = pd.DataFrame(num_attributes.kurtosis())

# concatenar
df_num_desc = pd.concat([num_min, num_max, num_range, num_mean, num_median, num_std,num_skew, num_kurtosis], 
                        axis=1)

df_num_desc.columns = ['Min', 'Max', 'Range', 'Mean', 'Median', 'STD', 'Skew', 'Kurtosis']

# %%
df_num_desc
# Out:
#              Min   Max  Range       Mean  Median         STD       Skew  \
# age            1  2014   2013  44.325128    37.0  118.575881  16.392840
# signup_flow    0    25     25   3.151490     0.0    7.543933   2.287158
#
#                Kurtosis
# age          268.929431
# signup_flow    3.567794

# %%
# filtro acima de 120 anos
aux_1 = df_user_raw[df_user_raw['age'] > 120]
sns.distplot(aux_1['age'], kde=False);
# Out:
# /home/giovane/Documentos/repo/airbnb_previsao_agendamento/airbnb_booking/lib/python3.8/site-packages/seaborn/distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
# proporcao de classes acina de 120 anos 
aux_1['country_destination'].value_counts(normalize=True)
# Out:
# NDF      0.499331
# US       0.346720
# other    0.060241
# FR       0.024096
# IT       0.017403
# GB       0.013387
# ES       0.012048
# DE       0.009371
# CA       0.008032
# NL       0.006693
# AU       0.001339
# PT       0.001339
# Name: country_destination, dtype: float64

# %% [markdown]
# ### 1.5.2 Atributos Numericos - Sessao

# %%
# estatistica de tendencia central
num_mean = pd.DataFrame(num_attributes_sessions .mean()) 
num_median = pd.DataFrame(num_attributes_sessions .median())

# estatistica de dispersao 
num_std      = pd.DataFrame(num_attributes_sessions.std()) 
num_min      = pd.DataFrame(num_attributes_sessions.min())
num_max      = pd.DataFrame(num_attributes_sessions.max())
num_range    = pd.DataFrame(num_attributes_sessions.apply(lambda x : x.max()-x.min()))
num_skew     = pd.DataFrame(num_attributes_sessions.skew())
num_kurtosis = pd.DataFrame(num_attributes_sessions.kurtosis())

# concatenar
df_num_desc = pd.concat([num_min, num_max, num_range, num_mean, num_median, num_std,num_skew, num_kurtosis], 
                        axis=1)

df_num_desc.columns = ['Min', 'Max', 'Range', 'Mean', 'Median', 'STD', 'Skew', 'Kurtosis']

# %%
df_num_desc
# Out:
#               Min        Max      Range        Mean  Median          STD  \
# secs_elapsed  0.0  1799977.0  1799977.0  19961.8251  1369.0  88849.39327
#
#                    Skew   Kurtosis
# secs_elapsed  11.137761  154.84312

# %% [markdown]
# ### 1.5.3 Atributos Categoricos - Usuario

# %%
cat_attributes.drop('id', axis=1).describe()
# Out:
#            gender signup_method language affiliate_channel affiliate_provider  \
# count      207386        207386   207386            207386             207386
# unique          4             3       25                 8                 18
# top     -unknown-         basic       en            direct             direct
# freq        91783        148297   200415            134179             133935
#
#        first_affiliate_tracked signup_app first_device_type first_browser  \
# count                   207386     207386            207386        207386
# unique                       7          4                 9            52
# top                  untracked        Web       Mac Desktop        Chrome
# freq                    109232     178334             89600         63845
#
#        country_destination
# count               207386
# unique                  12
# top                    NDF
# freq                120216

# %% [markdown]
# ### 1.5.3 Atributos Categoricos - Sessao

# %%
cat_attributes_sessions.drop('user_id', axis=1).describe()
# Out:
#          action action_type        action_detail  device_type
# count   9213930     9213930              9213930      9213930
# unique      347          10                  155           14
# top        show        view  view_search_results  Mac Desktop
# freq    2178382     3545621              1770931      3019523

# %%
# Correlacao entre categorias 
x_columns = cat_attributes_sessions.drop('user_id', axis=1).columns.to_list()
y_columns = cat_attributes_sessions.drop('user_id', axis=1).columns.to_list()

cramer = {}

for x_col in x_columns: 
    corr = []
    for y_col in y_columns:
        corr.append(cramer_v(cat_attributes_sessions.loc[:, x_col], cat_attributes_sessions.loc[:, y_col]))
        
        cramer[x_col] = corr

# %%
df_cramer_cat = pd.DataFrame(cramer)
df_cramer_cat = df_cramer_cat.set_index([x_columns])
sns.heatmap(df_cramer_cat, annot=True);

# %% [markdown]
# # 2.0  Feature Engineering

# %%
df2 = df_user_raw.copy()

# %% [markdown]
# ## 2.1 Mapa Mental de Hipoteses

# %% [markdown]
# Criacao do Mapa mental de Hipotoses, levantando as analises para validacao de Hipoteses e quais atributos sera necessario devirar.

# %%
Image('../img/Booking_Destino.png')

# %% [markdown]
# ## 2.2 Levantamento de Hipoteses

# %% [markdown]
# **H01-** Em todos os destinos, os usuario levam 15 dias, em media para fazer a primeira reserva no Airbnb, desde sua primeira atividade.
#
# **H02-** Em todos os destinos, os usuarios levam 3 dias, em media, para fazer o cadastro no site.
#
# **H03-** O volume de reservas anual feitas durante o verao aumentaram 20% para destinos dentro dos USA.
#
# **H04-** Usuario do sexo feminino fazem 10% mais reservas para paises foram dos USA.
#
# **H05-** O canal de Marketing Google representam 40% das reservas para paises fora dos USA.
#
# **H06-** O destino dos USA representam mais de 20% em todos os canais.
#
# **H07-** A ideia media das pessoas é de 35 anos em todos os destinos.
#
# **H08-** A porcentagem de usuarios que usam o site na lingua ingles-americano para reservar em qualquer destino é maior que 90%?
#
# **H09-** O numero de reservas do Airbnb é crescente ou decrescente ao longo dos anos?

# %% [markdown]
# ## 2.3 Lista Final de Hipoteses

# %% [markdown]
# ## 2.4 Feature Engineering

# %%
# criacao de a tributos para a EDA
# dias do cadastro ate o bookin 
df2['days_account_created_booking'] = (df2['date_first_booking'] - df2['date_account_created']).apply(lambda x : x.days)

# dias da primeira acao ate o booking 
df2['days_first_active_booking'] = (df2['date_first_booking'] - pd.to_datetime(df2['timestamp_first_active'].dt.strftime('%Y-%m-%d'))).apply(lambda x : x.days)

# dias da primeira acao ate o cadastro 
df2['days_first_active_account_created'] = (df2['date_account_created'] - pd.to_datetime(df2['timestamp_first_active'].dt.strftime('%Y-%m-%d'))).apply(lambda x : x.days)

# ======= date_account_created =======
# day 
df2['day_account_created'] = df2['date_account_created'].dt.day

# month 
df2['month_account_created'] = df2['date_account_created'].dt.month

# year 
df2['year_account_created'] = df2['date_account_created'].dt.year 

# day of week 
df2['dayweek_account_created'] = df2['date_account_created'].dt.dayofweek

# week of year 
df2['weekyear_account_created'] = df2['date_account_created'].dt.weekofyear


# ======= timestamp_first_active =======
# day
df2['day_first_active'] = df2['timestamp_first_active'].dt.day

# month 
df2['month_first_active'] = df2['timestamp_first_active'].dt.month

# year 
df2['year_first_active'] = df2['timestamp_first_active'].dt.year 

# day of week 
df2['dayweek_first_active'] = df2['timestamp_first_active'].dt.dayofweek

# week of year 
df2['weekyear_first_active'] = df2['timestamp_first_active'].dt.weekofyear

# ======= date_first_booking =======
# day
df2['day_first_booking'] = df2['date_first_booking'].dt.day

# month 
df2['month_first_booking'] = df2['date_first_booking'].dt.month

# year 
df2['year_first_booking'] = df2['date_first_booking'].dt.year 

# day of week 
df2['dayweek_first_booking'] = df2['date_first_booking'].dt.dayofweek

# week of year 
df2['weekyear_first_booking'] = df2['date_first_booking'].dt.weekofyear
# Out:
# /tmp/ipykernel_4201/1190674166.py:25: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df2['weekyear_account_created'] = df2['date_account_created'].dt.weekofyear
# /tmp/ipykernel_4201/1190674166.py:42: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df2['weekyear_first_active'] = df2['timestamp_first_active'].dt.weekofyear
# /tmp/ipykernel_4201/1190674166.py:58: FutureWarning: Series.dt.weekofyear and Series.dt.week have been deprecated.  Please use Series.dt.isocalendar().week instead.
#   df2['weekyear_first_booking'] = df2['date_first_booking'].dt.weekofyear

# %% [markdown]
# # 3.0 Filtragem de Dados

# %%
df3 = df2.copy()

# %% [markdown]
# ## 3.1 Filtrangem de Linhas

# %%
# fintrando idade entre 15 a 120 
df3 = df3[(df3['age'] > 15) &  (df3['age'] < 120)]

# filtrando secs_elapsed maiores que 0 segundos
#df_sessions_raw = df_sessions_raw[df_sessions_raw['secs_elapsed'] > 0]

# %% [markdown]
# ## 3.2 Filtragem de Colunas

# %%
#removendo atributos que nao existem no momento da predicao 
df3.drop(['id', 'timestamp_first_active', 'date_first_booking', 'date_account_created'], axis=1, inplace=True)

# %% [markdown]
# # 4.0  Analise Exploratoria de Dados

# %%
df4 = df3.copy()

# %% [markdown]
# ## 4.1 Analise Univariada

# %%
profilerep = ProfileReport(df4.reset_index(drop=True))
profilerep.to_file('report_univariada.html')
# Out:
# Summarize dataset:   0%|          | 0/5 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# File /usr/lib/python3.8/multiprocessing/pool.py:851, in IMapIterator.next(self, timeout)
#     850 try:
# --> 851     item = self._items.popleft()
#     852 except IndexError:
#
# IndexError: pop from an empty deque
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [26], in <cell line: 2>()
#       1 profilerep = ProfileReport(df4.reset_index(drop=True))
# ----> 2 profilerep.to_file('report_univariada.html')
#
# File ~/Documentos/repo/airbnb_previsao_agendamento/airbnb_booking/lib/python3.8/site-packages/pandas_profiling/profile_report.py:257, in ProfileReport.to_file(self, output_file, silent)
#     254         self.config.html.assets_prefix = str(output_file.stem) + "_assets"
#     255     create_html_assets(self.config, output_file)
# --> 257 data = self.to_html()
#     259 if output_file.suffix != ".html":
#     260     suffix = output_file.suffix
#
# File ~/Documentos/repo/airbnb_previsao_agendamento/airbnb_booking/lib/python3.8/site-packages/pandas_profiling/profile_report.py:368, in ProfileReport.to_html(self)
#     360 def to_html(self) -> str:
#     361     """Generate and return complete template as lengthy string
#     362         for using with frameworks.
#     363
#    (...)
#     366
#     367     """
# --> 368     return self.html
#
# File ~/Documentos/repo/airbnb_previsao_agendamento/airbnb_booking/lib/python3.8/site-packages/pandas_profiling/profile_report.py:185, in ProfileReport.html(self)
#     182 @property
#     183 def html(self) -> str:
#     184     if self._html is None:
# --> 185         self._html = self._render_html()
#     186     return self._html
#
# File ~/Documentos/repo/airbnb_previsao_agendamento/airbnb_booking/lib/python3.8/site-packages/pandas_profiling/profile_report.py:287, in ProfileReport._render_html(self)
#     284 def _render_html(self) -> str:
#     285     from pandas_profiling.report.presentation.flavours import HTMLReport
# --> 287     report = self.report
#     289     with tqdm(
#     290         total=1, desc="Render HTML", disable=not self.config.progress_bar
#     291     ) as pbar:
#     292         html = HTMLReport(copy.deepcopy(report)).render(
#     293             nav=self.config.html.navbar_show,
#     294             offline=self.config.html.use_local_assets,
#    (...)
#     302             version=self.description_set["package"]["pandas_profiling_version"],
#     303         )
#
# File ~/Documentos/repo/airbnb_previsao_agendamento/airbnb_booking/lib/python3.8/site-packages/pandas_profiling/profile_report.py:179, in ProfileReport.report(self)
#     176 @property
#     177 def report(self) -> Root:
#     178     if self._report is None:
# --> 179         self._report = get_report_structure(self.config, self.description_set)
#     180     return self._report
#
# File ~/Documentos/repo/airbnb_previsao_agendamento/airbnb_booking/lib/python3.8/site-packages/pandas_profiling/profile_report.py:161, in ProfileReport.description_set(self)
#     158 @property
#     159 def description_set(self) -> Dict[str, Any]:
#     160     if self._description_set is None:
# --> 161         self._description_set = describe_df(
#     162             self.config,
#     163             self.df,
#     164             self.summarizer,
#     165             self.typeset,
#     166             self._sample,
#     167         )
#     168     return self._description_set
#
# File ~/Documentos/repo/airbnb_previsao_agendamento/airbnb_booking/lib/python3.8/site-packages/pandas_profiling/model/describe.py:71, in describe(config, df, summarizer, typeset, sample)
#      69 # Variable-specific
#      70 pbar.total += len(df.columns)
# ---> 71 series_description = get_series_descriptions(
#      72     config, df, summarizer, typeset, pbar
#      73 )
#      75 pbar.set_postfix_str("Get variable types")
#      76 pbar.total += 1
#
# File ~/Documentos/repo/airbnb_previsao_agendamento/airbnb_booking/lib/python3.8/site-packages/multimethod/__init__.py:300, in multimethod.__call__(self, *args, **kwargs)
#     298 func = self[tuple(func(arg) for func, arg in zip(self.type_checkers, args))]
#     299 try:
# --> 300     return func(*args, **kwargs)
#     301 except TypeError as ex:
#     302     raise DispatchError(f"Function {func.__code__}") from ex
#
# File ~/Documentos/repo/airbnb_previsao_agendamento/airbnb_booking/lib/python3.8/site-packages/pandas_profiling/model/pandas/summary_pandas.py:92, in pandas_get_series_descriptions(config, df, summarizer, typeset, pbar)
#      89 else:
#      90     # TODO: use `Pool` for Linux-based systems
#      91     with multiprocessing.pool.ThreadPool(pool_size) as executor:
# ---> 92         for i, (column, description) in enumerate(
#      93             executor.imap_unordered(multiprocess_1d, args)
#      94         ):
#      95             pbar.set_postfix_str(f"Describe variable:{column}")
#      96             series_description[column] = description
#
# File /usr/lib/python3.8/multiprocessing/pool.py:856, in IMapIterator.next(self, timeout)
#     854     self._pool = None
#     855     raise StopIteration from None
# --> 856 self._cond.wait(timeout)
#     857 try:
#     858     item = self._items.popleft()
#
# File /usr/lib/python3.8/threading.py:302, in Condition.wait(self, timeout)
#     300 try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     301     if timeout is None:
# --> 302         waiter.acquire()
#     303         gotit = True
#     304     else:
#
# KeyboardInterrupt:

# %% [markdown]
# **Atributos correlacionaveis para remocao**
#
# days_first_active_booking  x days_account_created_booking
# - remover - days_first_active_booking
#
# day_first_active x day_account_created
# - remover - day_first_active
#
# month_first_active x month_account_created
# - remover - month_first_active
#
# year_first_active x year_account_created
# - remover - year_first_active
#
# dayweek_first_active x dayweek_account_created
# - remover - dayweek_first_active
#
# weekyear_first_active x  weekyear_account_created
# - remover - weekyear_first_active
#
# weekyear_account_created x month_account_created
# - remover - month_account_created
#
# weekyear_first_booking x month_first_booking
# - remover - month_first_booking

# %% [markdown]
# ## 4.2 Analise Bivariada - Validacao de Hipotese

# %% [markdown]
# ### H01- Em todos os destinos, os usuario levam 15 dias, em media para fazer a primeira reserva no Airbnb, desde sua primeira atividade.
# **Verdadeiro** O usuario leva ate 5 em media para fazer sua primeira reserva desde sua primeira atividade

# %%
df4[['country_destination', 'days_first_active_booking']].groupby('country_destination').median()
# Out:
#                      days_first_active_booking
# country_destination
# AU                                         5.0
# CA                                         3.0
# DE                                         4.0
# ES                                         4.0
# FR                                         4.0
# GB                                         4.0
# IT                                         3.0
# NDF                                      632.0
# NL                                         3.0
# PT                                         4.0
# US                                         3.0
# other                                      4.0

# %%
aux = df4[(df4['country_destination']!= 'NDF') & ( df4['days_first_active_booking']<200) ] 
sns.boxplot(x = aux['country_destination'], y = aux['days_first_active_booking']);

# %%
sns.histplot(aux['days_first_active_booking']);

# %% [markdown]
# ### H02- Em todos os destinos, os usuarios levam 3 dias, em media, para fazer o cadastro no site.
# **Verdadeiro** Para todos os destinos o usuario leva de 0 a 2 dias para realizar o cadastro apos sua primeira interacao com o Airbnb

# %%
# Numero de dias do usuario para cadastro no site por destino. 
aux = df4[['country_destination', 'days_first_active_account_created']].groupby('country_destination').mean().reset_index()
sns.barplot(x='country_destination', y = 'days_first_active_account_created', data = aux.sort_values('days_first_active_account_created'));

# %%
sns.boxplot(x = df4['country_destination'], y = df4['days_first_active_account_created']);

# %% [markdown]
# ### H03- O volume de reservas anual feitas durante o verao aumentaram 20% para destinos dentro dos USA.
# **Falso** Para no ultimo ano, de 2014 a 2015 tivemos um queda de 99% nas resevas para os USA

# %%
# filtro dos meses do verao
summer_month = [6, 7, 8]
df_filter_summer = df4[(df4['country_destination']=='US') & df4['month_first_booking'].isin(summer_month)]

# Numero de reservas ao longo dos anos
plt.subplot(1,2, 1)
aux = df_filter_summer[['country_destination', 'year_first_booking']].groupby(['year_first_booking']).size().reset_index().rename(columns = {0:'booking'})
plt.title('Reservas no verao ao longo dos anos')
sns.barplot(x = 'year_first_booking', y = 'booking', data = aux);

plt.subplot(1,2, 2)
# numero de reservas por mes do verao ao longo dos anos 
aux = df_filter_summer[['country_destination', 'year_first_booking', 'month_first_booking']].groupby(['year_first_booking', 'month_first_booking']).size().reset_index().rename(columns = {0:'booking'})
plt.title('Reservas nos meses de verao ao longo dos anos')
sns.barplot(x = 'year_first_booking', y = 'booking', hue = 'month_first_booking',data = aux);

# %%
# crescimento de reservas atravers dos anos em porcentagem 
aux['delta'] = aux['booking'].pct_change()*100
aux
# Out:
#    year_first_booking  booking       delta
# 0                2010      240         NaN
# 1                2011      953  297.083333
# 2                2012     3328  249.213012
# 3                2013     6306   89.483173
# 4                2014     5842   -7.358072
# 5                2015       44  -99.246833

# %%
# numero de reservas ao longo dos meses, no periodo 2010 a 2015
df_filter_summer = df4[df4['country_destination']=='US']
aux = df_filter_summer[['country_destination', 'year_first_booking', 'month_first_booking']].groupby(['country_destination',  'year_first_booking', 'month_first_booking']).size().reset_index().rename(columns = {0:'booking'})

sns.barplot(x = 'year_first_booking', y = 'booking', hue = 'month_first_booking',data = aux);

# %% [markdown]
# Como visto no primeiro grafico, ate o ano de 2013 existia um aumento anual nas reservas par destinos US. DO mesmo modo para o ano de 2014 e 2015 é apresentada uma queda nas reserva.
#
# Verificando o ano de 2015 foi possivel ver que o mesmo nao possui o periodo de verao completo, podendo levar em uma interpretacao errada. Logo, no ano de 2014 apos o mes 6 se inicia a queda que se prolonga ate o ultimo mes disponivel no ano de 2015.

# %% [markdown]
# ### H04- Usuario do sexo feminino fazem 10% mais reservas para paises fora dos USA
# **Falso** Usuarios do sexo feminino fazer mais reservas para USA.

# %%
# reservas para paises sem USA por genero
df_filter= df4[(df4['country_destination']!= 'NDF') & (df4['country_destination']!= 'US')]
aux =df_filter.groupby(['gender', 'country_destination']).size().reset_index().rename(columns=  {0:'booking'}).sort_values('booking')
aux['booking'] = aux['booking'].apply( lambda x : x/df_filter.shape[0]*100) 

plt.subplot(1, 2, 1)
sns.barplot(x = aux['country_destination'], y = aux['booking'], hue = aux['gender']);


# reservas por genero no USA 
df_filter= df4[df4['country_destination']== 'US']
aux =df_filter.groupby(['gender', 'country_destination']).size().reset_index().rename(columns=  {0:'booking'}).sort_values('booking')
aux['booking'] = aux['booking'].apply( lambda x : x/df_filter.shape[0]*100) 

plt.subplot(1, 2, 2)
sns.barplot(x = aux['country_destination'], y = aux['booking'], hue = aux['gender']);

# %%
# reservas para paises sem USA por genero
df_filter= df4[(df4['country_destination']!= 'NDF') & (df4['country_destination']!= 'US')]
aux =df_filter.groupby('gender').size().reset_index().rename(columns=  {0:'booking'}).sort_values('booking')
aux['booking'] = aux['booking'].apply( lambda x : x/df_filter.shape[0]*100) 


sns.barplot(x = aux['gender'], y = aux['booking']);

# %% [markdown]
# ### H05- O canal de Marketing Google representam 40% das reservas para paises fora dos USA.
# **Falso** O canal de marketing do Google representa 25% das reservas no paises fora USA

# %%
# filtro de paises sem USA
country_list = ['US', 'NDF']
df_filter = df4[~df4['country_destination'].isin(country_list)]

#porcentagem de reservas por canal 
df_group = df_filter.groupby(['affiliate_provider']).size().reset_index().rename(columns=  {0:'booking'}).sort_values('booking')

df_group['booking'] = df_group['booking'].apply(lambda x : x / df_filter.shape[0]*100)

plt.subplot(1,2, 1 )
sns.barplot( x = 'affiliate_provider', y = 'booking', data = df_group);
plt.xticks(rotation=70);

# filtro USA
df_filter = df4[df4['country_destination']=='US']

#porcentagem de reservas por canal 
df_group = df_filter.groupby(['affiliate_provider']).size().reset_index().rename(columns=  {0:'booking'}).sort_values('booking')

df_group['booking'] = df_group['booking'].apply(lambda x : x / df_filter.shape[0]*100)
plt.subplot(1,2, 2)
sns.barplot( x = 'affiliate_provider', y = 'booking', data = df_group);
plt.xticks(rotation=70);

# %% [markdown]
# ### H06- O destino dos USA representam mais de 20% em todos os canais.

# %%
df_filter = df4[df4['country_destination']=='US']

df_filter.groupby('affiliate_provider').size()/df4.shape[0]*100
# Out:
# affiliate_provider
# baidu                   0.002904
# bing                    0.257511
# craigslist              0.583272
# direct                 19.738810
# email-marketing         0.013069
# facebook                0.239602
# facebook-open-graph     0.047436
# google                  6.568954
# gsp                     0.012585
# meetup                  0.016457
# naver                   0.004840
# other                   1.701897
# padmapper               0.103101
# vast                    0.078899
# yahoo                   0.058569
# yandex                  0.001936
# dtype: float64

# %% [markdown]
# ### H07- A ideia media das pessoas é de 35 anos em todos os destinos.
# **verdadeiro** Entre todos destionos a idade media é de 35 anos.

# %%
df_filter = df4[['age', 'country_destination']]

# %%
aux = df_filter.groupby('country_destination').mean().reset_index()
sns.barplot(x = 'country_destination', y = 'age', data = aux );

# %% [markdown]
# ### H08- A porcentagem de usuarios que usam o site na lingua ingles-americano para reservar em qualquer destino é maior que 90%?
# **Verdadeiro** Cerca de 96% dos usuarios usam a lingua inglesa para as reservas.

# %%
df_language = (df4.groupby('language').size()/df4.shape[0]*100).reset_index().rename(columns = {0: 'booking'})
sns.barplot(x = 'language', y = 'booking', data = df_language);

# %% [markdown]
# ### H09- O numero de reservas do Airbnb é crescente ou decrescente ao longo dos anos?
# **Decrescente**

# %%
# reservas ao longo dos anos 
df_year = df4.groupby('year_first_booking').size().reset_index().rename(columns = {0: 'booking'})
plt.subplot(1, 2, 1)
plt.title('Reservas por ano ')
sns.lineplot(x = 'year_first_booking', y = 'booking', data = df_year);

# reservas ao longo dos anos com 'NDF' removido 
df_filter_ndf = df4[df4['country_destination']!='NDF']
df_year = df_filter_ndf.groupby('year_first_booking').size().reset_index().rename(columns = {0: 'booking'})
plt.subplot(1, 2, 2)
plt.title('Reservas por ano sem NDF')
sns.lineplot(x = 'year_first_booking', y = 'booking', data = df_year);

# %%
# concentracao de reservas entre os destinos em 2015
aux = df4[(df4['year_first_booking'] == 2015) & (df4['country_destination']!='NDF')]
aux = aux.groupby(['month_first_booking', 'country_destination']).size().reset_index().rename(columns = {0: 'booking'})

plt.subplot(1, 2, 1)
sns.barplot(x = 'country_destination', y = 'booking', hue = 'month_first_booking', data = aux);

# NDF em 2015 
aux = df4[(df4['year_first_booking'] == 2015) & (df4['country_destination']=='NDF')]
aux = aux.groupby(['month_first_booking', 'country_destination']).size().reset_index().rename(columns = {0: 'booking'})

plt.subplot(1, 2, 2)
sns.barplot(x = 'country_destination', y = 'booking', hue = 'month_first_booking', data = aux);

# %% [markdown]
# A classe de destino que faz com que 2015 seja o maior ano em reservas é a NDF(nao fez reserva).
#
# Se conseideramos a exclusao das linhas de NDF(onde o usuario nao realisou reservas) existe um crescimento ate 2014 e a partir de 2015 se inicia uma queda nas reserva. Isso pode se dar por conta do ano de 2015 nao estar com os meses fechados, indo ate o mes 6

# %% [markdown]
# ## 4.3 Analise Multivariada

# %%
num_attributes = df4.select_dtypes(include=['int64', 'float64']).columns.to_list()
corr = df4[num_attributes].corr(method = 'pearson')
sns.heatmap(corr , annot = True);
plt.yticks(rotation='horizontal');

# %% [markdown]
# # 5.0 Balanceamento de Dados

# %%
df5 = df4.copy()

# %%
df5['country_destination'].value_counts()
# Out:
# NDF      119810
# US        60800
# other      9935
# FR         4881
# IT         2776
# GB         2285
# ES         2203
# CA         1385
# DE         1033
# NL          746
# AU          526
# PT          213
# Name: country_destination, dtype: int64

# %% [markdown]
# ##  4.1 Smote + Tomeklink

# %%
num_attributes = df5.select_dtypes(include=['int64', 'float64']).columns.to_list()
cat_attributes = df5.select_dtypes(exclude=['int64', 'float64', 'datetime64[ns]']).drop(['country_destination'], axis=1).columns.to_list()

encoder_gender = pp.LabelEncoder()
encoder_signup_method = pp.LabelEncoder()
encoder_language = pp.LabelEncoder()
encoder_affiliate_channel = pp.LabelEncoder()
encoder_affiliate_provider = pp.LabelEncoder()
encoder_first_affiliate_tracked = pp.LabelEncoder()
encoder_signup_app = pp.LabelEncoder()
encoder_first_device_type = pp.LabelEncoder()
encoder_first_browser = pp.LabelEncoder()


df5_dummy = df5[cat_attributes].copy()
df5_dummy['gender'] = encoder_gender.fit_transform(df5_dummy['gender'])
df5_dummy['signup_method'] = encoder_signup_method.fit_transform(df5_dummy['signup_method'])
df5_dummy['language'] = encoder_language.fit_transform(df5_dummy['language'])
df5_dummy['affiliate_channel'] = encoder_affiliate_channel.fit_transform(df5_dummy['affiliate_channel'])
df5_dummy['affiliate_provider'] = encoder_affiliate_provider.fit_transform(df5_dummy['affiliate_provider'])
df5_dummy['first_affiliate_tracked'] = encoder_first_affiliate_tracked.fit_transform(df5_dummy['first_affiliate_tracked'])
df5_dummy['signup_app'] = encoder_signup_app.fit_transform(df5_dummy['signup_app'])
df5_dummy['first_device_type'] = encoder_first_device_type.fit_transform(df5_dummy['first_device_type'])
df5_dummy['first_browser'] = encoder_first_browser.fit_transform(df5_dummy['first_browser'])



df5_encoded = pd.concat([df5[num_attributes], df5_dummy], axis=1)

# %%
ratio_balanced =  {'NDF': 119810,
                   'US':  60800,
                   'other': 6*9935,
                   'FR': 12*4881,
                   'IT': 20*2776,
                   'GB': 30*2285,
                   'ES': 30*2203,
                   'CA': 40*1385,
                   'DE': 45*1033,
                   'NL': 80*746,
                   'AU': 85*526,
                   'PT': 300*213}

# %%
sampler = combine.SMOTETomek(sampling_strategy=ratio_balanced ,random_state=42, n_jobs= -1)
x_sample, y_sample = sampler.fit_resample(df5_encoded, df5['country_destination'])

# %%
y_sample.value_counts()
# Out:
# NDF      119808
# GB        68428
# ES        65946
# PT        63894
# NL        59654
# US        59427
# other     58702
# FR        58226
# CA        55321
# IT        55307
# DE        46441
# AU        44699
# Name: country_destination, dtype: int64

# %%
# atributos numericos 
df_balanced_num = x_sample[num_attributes]

#atributos categoricos 
df_balanced_cat = x_sample.drop(num_attributes, axis=1)

df_balanced_cat['gender'] = encoder_gender.inverse_transform(df_balanced_cat['gender'])
df_balanced_cat['signup_method'] = encoder_signup_method.inverse_transform(df_balanced_cat['signup_method'])
df_balanced_cat['language'] = encoder_language.inverse_transform(df_balanced_cat['language'])
df_balanced_cat['affiliate_channel'] = encoder_affiliate_channel.inverse_transform(df_balanced_cat['affiliate_channel'])
df_balanced_cat['affiliate_provider'] = encoder_affiliate_provider.inverse_transform(df_balanced_cat['affiliate_provider'])
df_balanced_cat['first_affiliate_tracked'] = encoder_first_affiliate_tracked.inverse_transform(df_balanced_cat['first_affiliate_tracked'])
df_balanced_cat['signup_app'] = encoder_signup_app.inverse_transform(df_balanced_cat['signup_app'])
df_balanced_cat['first_device_type'] = encoder_first_device_type.inverse_transform(df_balanced_cat['first_device_type'])
df_balanced_cat['first_browser'] = encoder_first_browser.inverse_transform(df_balanced_cat['first_browser'])

#concatenando numerico e categorico 
df_balanced = pd.concat([df_balanced_num, df_balanced_cat], axis=1)
df_balanced['country_destination'] = y_sample

# %% [markdown]
# # 6.0 Modelagem de Dados

# %%
df6 = df_balanced.copy()

# %% [markdown]
# **Atributos correlacionaveis para remocao**
#
# days_first_active_booking  x days_account_created_booking
# - remover - days_first_active_booking
#
# day_first_active x day_account_created
# - remover - day_first_active
#
# month_first_active x month_account_created
# - remover - month_first_active
#
# year_first_active x year_account_created
# - remover - year_first_active
#
# dayweek_first_active x dayweek_account_created
# - remover - dayweek_first_active
#
# weekyear_first_active x  weekyear_account_created
# - remover - weekyear_first_active
#
# weekyear_account_created x month_account_created
# - remover - month_account_created
#
# weekyear_first_booking x month_first_booking
# - remover - month_first_booking

# %%
df6.drop(['days_first_active_booking', 'day_first_active', 'month_first_active', 'year_first_active', 'dayweek_first_active', 
           'weekyear_first_active', 'month_account_created', 'month_first_booking', 'first_browser', 'language', 'first_device_type', 'year_first_booking', 'language', 'affiliate_provider'], axis = 1, inplace = True)

# %% [markdown]
# ## 6.1 Reescala

# %%
mms = pp.MinMaxScaler()
rs = pp.RobustScaler()
ss = pp.StandardScaler()

# %%
# MinMax 
# age
df6['age'] = mms.fit_transform(df6[['age']].values)

# year_account_created
df6['year_account_created'] = mms.fit_transform(df6[['year_account_created']].values)


# RobustScaler 
# days_first_active_account_created
df6['days_first_active_account_created'] = rs.fit_transform(df6[['days_first_active_account_created']].values)

# days_account_created_booking
df6['days_account_created_booking'] = rs.fit_transform(df6[['days_account_created_booking']].values)

# %% [markdown]
# ## 6.2 Encoding

# %%
# hot encoder 
# gender
df6 = pd.get_dummies(df6, prefix=['gender'], columns=['gender'])

# signup_method
df6 = pd.get_dummies(df6, prefix=['signup_method'], columns=['signup_method'])

# signup_app
df6 = pd.get_dummies(df6, prefix=['signup_app'], columns=['signup_app'])

# target encoder 
te = TargetEncoder()
country_map = {'NDF':0 , 'US':1, 'other': 2, 'CA':3, 'FR':4, 'ES':5, 'GB':6, 'IT':7, 'PT':8, 'NL':9, 'DE':10, 'AU':11}

# affiliate_channel 
df6['affiliate_channel'] = te.fit_transform(df6[['affiliate_channel']].values, df6['country_destination'].map(country_map))

# first_affiliate_tracked
df6['first_affiliate_tracked'] = te.fit_transform(df6[['first_affiliate_tracked']].values, df6['country_destination'].map(country_map))

# %% [markdown]
# ## 6.3 Transformacao

# %%
# day_first_booking
df6['day_first_booking_sin'] = df6['day_first_booking'].apply(lambda x: np.sin(x * (2. * np.pi/30)))
df6['day_first_booking_cos'] = df6['day_first_booking'].apply(lambda x: np.cos(x * (2. * np.pi/30)))

# day_account_created
df6['day_account_created_sin'] = df6['day_account_created'].apply(lambda x: np.sin(x * (2. * np.pi/30)))
df6['day_account_created_cos'] = df6['day_account_created'].apply(lambda x: np.cos(x * (2. * np.pi/30)))

# weekyear_first_booking
df6['weekyear_first_booking_sin'] = df6['weekyear_first_booking'].apply(lambda x: np.sin(x * (2. * np.pi/52)))
df6['weekyear_first_booking_cos'] = df6['weekyear_first_booking'].apply(lambda x: np.cos(x * (2. * np.pi/52)))

# weekyear_account_created
df6['weekyear_account_created_sin'] = df6['weekyear_account_created'].apply(lambda x: np.sin(x * (2. * np.pi/52)))
df6['weekyear_account_created_cos'] = df6['weekyear_account_created'].apply(lambda x: np.cos(x * (2. * np.pi/52)))

# dayweek_account_created
df6['dayweek_account_created_sin'] = df6['dayweek_account_created'].apply(lambda x: np.sin(x * (2. * np.pi/7)))
df6['dayweek_account_created_cos'] = df6['dayweek_account_created'].apply(lambda x: np.cos(x * (2. * np.pi/7)))

# dayweek_first_booking
df6['dayweek_first_booking_sin'] = df6['dayweek_first_booking'].apply(lambda x: np.sin(x * (2. * np.pi/7)))
df6['dayweek_first_booking_cos'] = df6['dayweek_first_booking'].apply(lambda x: np.cos(x * (2. * np.pi/7)))

# %% [markdown]
# # 7.0 Selecao de Atributos

# %%
df7= df6.copy()

# %% [markdown]
# ## 7.1  Selecao de Atributos Colineares

# %%
#df7.drop(['days_first_active_booking', 'day_first_active', 'month_first_active', 'year_first_active', 'dayweek_first_active', 
           #'weekyear_first_active', 'month_account_created', 'month_first_booking', 'first_browser'], axis = 1, inplace = True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Input In [68], in <cell line: 1>()
# ----> 1 df6.drop(['days_first_active_booking', 'day_first_active', 'month_first_active', 'year_first_active', 'dayweek_first_active',
#       2            'weekyear_first_active', 'month_account_created', 'month_first_booking', 'first_browser'], axis = 1, inplace = True)
#
# File ~/Documentos/repo/airbnb_previsao_agendamento/airbnb_booking/lib/python3.8/site-packages/pandas/util/_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File ~/Documentos/repo/airbnb_previsao_agendamento/airbnb_booking/lib/python3.8/site-packages/pandas/core/frame.py:4906, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4774 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    4775 def drop(
#    4776     self,
#    (...)
#    4783     errors: str = "raise",
#    4784 ):
#    4785     """
#    4786     Drop specified labels from rows or columns.
#    4787
#    (...)
#    4904             weight  1.0     0.8
#    4905     """
# -> 4906     return super().drop(
#    4907         labels=labels,
#    4908         axis=axis,
#    4909         index=index,
#    4910         columns=columns,
#    4911         level=level,
#    4912         inplace=inplace,
#    4913         errors=errors,
#    4914     )
#
# File ~/Documentos/repo/airbnb_previsao_agendamento/airbnb_booking/lib/python3.8/site-packages/pandas/core/generic.py:4150, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148 for axis, labels in axes.items():
#    4149     if labels is not None:
# -> 4150         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4152 if inplace:
#    4153     self._update_inplace(obj)
#
# File ~/Documentos/repo/airbnb_previsao_agendamento/airbnb_booking/lib/python3.8/site-packages/pandas/core/generic.py:4185, in NDFrame._drop_axis(self, labels, axis, level, errors)
#    4183         new_axis = axis.drop(labels, level=level, errors=errors)
#    4184     else:
# -> 4185         new_axis = axis.drop(labels, errors=errors)
#    4186     result = self.reindex(**{axis_name: new_axis})
#    4188 # Case for non-unique axis
#    4189 else:
#
# File ~/Documentos/repo/airbnb_previsao_agendamento/airbnb_booking/lib/python3.8/site-packages/pandas/core/indexes/base.py:6017, in Index.drop(self, labels, errors)
#    6015 if mask.any():
#    6016     if errors != "ignore":
# -> 6017         raise KeyError(f"{labels[mask]} not found in axis")
#    6018     indexer = indexer[~mask]
#    6019 return self.delete(indexer)
#
# KeyError: "['first_browser'] not found in axis"

# %% [markdown]
# # 8.0 Modelagem Machine Learning

# %%
df8 = df7.copy()

# %% [markdown]
# ## 8.1 Separar Dados Teste e Validação

# %%
x = df8.drop('country_destination', axis=1)
y = df8['country_destination'].copy()

# %%
x_train, x_test, y_train, y_test = ms.train_test_split(x, y, test_size=0.2, random_state=42)

# %% [markdown]
# ## 8.2 Modelo Baseline

# %%
l_country_destination = df8['country_destination'].sort_values().unique()
country_destination_weights = df8['country_destination'].value_counts(normalize=True).sort_index().tolist()
k_num = y_test.shape[0]

# Modelo de classificacao aleatoria
yhat_random = random.choices(population=l_country_destination, k=k_num, weights= country_destination_weights )

# %% [markdown]
# ### 8.2.1 Performance do Modelo - Baseline

# %%
# acuracia 
acuracia_random = metrics.accuracy_score(y_test, yhat_random)
print('Acuracia:{}'.format(acuracia_random))

# Acuracia balanceada 
balanced_accuracy_random = metrics.balanced_accuracy_score(y_test, yhat_random)
print('Acuracia Balanceada: {}'.format(balanced_accuracy_random))

# kappa 
kappa_random = metrics.cohen_kappa_score(y_test, yhat_random)
print('Kappa: {}'.format(kappa_random))

print(metrics.classification_report(y_test, yhat_random))

# Matriz de confusao
mt.plot_confusion_matrix(y_test, yhat_random, normalize=False, figsize=(12,12));
# Out:
# Acuracia:0.0911153594274034
# Acuracia Balanceada: 0.08410446107725265
# Kappa: 0.00098613066975628
#               precision    recall  f1-score   support
#
#           AU       0.06      0.06      0.06      8950
#           CA       0.07      0.07      0.07     10974
#           DE       0.06      0.06      0.06      9218
#           ES       0.09      0.09      0.09     13116
#           FR       0.08      0.08      0.08     11799
#           GB       0.09      0.09      0.09     13723
#           IT       0.07      0.07      0.07     11136
#          NDF       0.16      0.16      0.16     23788
#           NL       0.08      0.08      0.08     12010
#           PT       0.08      0.08      0.08     12795
#           US       0.08      0.08      0.08     11966
#        other       0.08      0.08      0.08     11696
#
#     accuracy                           0.09    151171
#    macro avg       0.08      0.08      0.08    151171
# weighted avg       0.09      0.09      0.09    151171

# %% [markdown]
# ## 8.3 Neural Network - MLP

# %%
# encode para variavel y 
encoder = pp.OneHotEncoder()
y_train_nn = encoder.fit_transform(y_train.values.reshape(-1,1)).toarray()

# %%
# definicao do modelo
model = ml.Sequential()
model.add(l.Dense(128, input_dim=x_train.shape[1], activation="relu"))
model.add(l.Dense(12, activation="softmax"))

# compilando modelo 
model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])

# treinamento 
model.fit(x_train, y_train_nn, epochs=100, verbose = 0)
# Out:
# 2022-04-19 15:46:19.844545: W tensorflow/stream_executor/platform/default/dso_loader.cc:64] Could not load dynamic library 'libcuda.so.1'; dlerror: libcuda.so.1: cannot open shared object file: No such file or directory
# 2022-04-19 15:46:19.844572: W tensorflow/stream_executor/cuda/cuda_driver.cc:269] failed call to cuInit: UNKNOWN ERROR (303)
# 2022-04-19 15:46:19.844588: I tensorflow/stream_executor/cuda/cuda_diagnostics.cc:156] kernel driver does not appear to be running on this host (giovane-VirtualBox): /proc/driver/nvidia/version does not exist
# 2022-04-19 15:46:19.850722: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %% [markdown]
# ### 8.3.1 Performance do Modelo - MLP

# %%
# predicao 
pred = model.predict(x_test)

# invertendo o encoder 
yhat_nn = encoder.inverse_transform(pred)

y_test_nn = y_test.to_numpy()
yhat_nn = yhat_nn.reshape(1,-1)[0]

# %%
# acuracia 
acuracia_nn = metrics.accuracy_score(y_test_nn, yhat_nn)
print('Acuracia:{}'.format(acuracia_nn))

# Acuracia balanceada 
balanced_accuracy_nn = metrics.balanced_accuracy_score(y_test_nn, yhat_nn)
print('Acuracia Balanceada: {}'.format(balanced_accuracy_nn))

# kappa 
kappa_nn = metrics.cohen_kappa_score(y_test_nn, yhat_nn)
print('Kappa: {}'.format(kappa_nn))

print(metrics.classification_report(y_test_nn, yhat_nn))
# Out:
# Acuracia:0.4216417169959847
# Acuracia Balanceada: 0.36659267040701343
# Kappa: 0.36342231864254304
#               precision    recall  f1-score   support
#
#           AU       0.36      0.48      0.41      8950
#           CA       0.21      0.23      0.22     10974
#           DE       0.26      0.17      0.21      9218
#           ES       0.21      0.30      0.25     13116
#           FR       0.21      0.05      0.08     11799
#           GB       0.19      0.26      0.22     13723
#           IT       0.20      0.04      0.07     11136
#          NDF       1.00      1.00      1.00     23788
#           NL       0.31      0.51      0.38     12010
#           PT       0.66      0.82      0.74     12795
#           US       0.40      0.43      0.41     11966
#        other       0.20      0.09      0.12     11696
#
#     accuracy                           0.42    151171
#    macro avg       0.35      0.37      0.34    151171
# weighted avg       0.40      0.42      0.40    151171

# %%
# Matriz de confusao
mt.plot_confusion_matrix(y_test_nn, yhat_nn, normalize=False, figsize=(12,12));

# %% [markdown]
# O modelo acabou sendo inviesado, pelo fato do dataset estar desbalanceado. Podemos ver também que a acuracia de acimade 70%, as mesma também segue sendo inviesada pelo grande número de registro com US.

# %% [markdown]
# ### 8.3.2 Cross Validation - MLP

# %%
# gerar fold 
num_fold = 5 
kfold = ms.StratifiedKFold(n_splits= num_fold, shuffle=True, random_state=42)

l_balanced_acc =[]
l_kappa = []
i=1 

for train_ix, val_ix in kfold.split(x_train, y_train):
    print('Fold {}/{}'.format(i, num_fold))
    
    # fold 
    x_train_fold = x_train.iloc[train_ix]
    y_train_fold = y_train.iloc[train_ix]
    
    x_val_fold = x_train.iloc[val_ix]
    y_val_fold = y_train.iloc[val_ix]
    
    # encoder target
    encoder = pp.OneHotEncoder()
    y_train_fold_nn = encoder.fit_transform(y_train_fold.values.reshape(-1,1)).toarray()

    # definicao do modelo
    model = ml.Sequential()
    model.add(l.Dense(128, input_dim= x_train_fold.shape[1], activation="relu"))
    model.add(l.Dense(12, activation="softmax"))

    # compilando modelo 
    model.compile(loss = 'categorical_crossentropy', optimizer = 'adam', metrics=['accuracy'])

    # treinamento 
    model.fit( x_train_fold, y_train_fold_nn, epochs=100, batch_size = 42, verbose=0)

    # predicao 
    pred_nn = model.predict(x_val_fold)

    # invertendo o encoder 
    yhat_fold_nn = encoder.inverse_transform(pred_nn)

    y_val_fold_nn = y_val_fold.to_numpy()
    yhat_fold_nn = yhat_fold_nn.reshape(1,-1)[0]
    
    #metricas 
    ## Balanced Accuracy
    balanced_acc_fold = metrics.balanced_accuracy_score(y_val_fold_nn, yhat_fold_nn)
    l_balanced_acc.append(balanced_acc_fold)
    
    ##Kappa 
    kappa_fold = metrics.cohen_kappa_score(y_val_fold_nn, yhat_fold_nn)
    l_kappa.append(kappa_fold)
    
    i = i+1
# Out:
# Fold 1/5
# Fold 2/5
# Fold 3/5
# Fold 4/5
# Fold 5/5

# %%
print('Balanced Accuracy: {:.4f}+/-{:.4f}'.format(np.mean(l_balanced_acc), np.std(l_balanced_acc)) )
print('Kappa: {:.4f}+/-{:.4f}'.format(np.mean(l_kappa), np.std(l_kappa)) )
# Out:
# Balanced Accuracy: 0.3664+/-0.0030
# Kappa: 0.3633+/-0.0032
